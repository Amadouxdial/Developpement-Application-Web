# %%
import pandas as pd

def load_df(filepath="data/fleuriste.csv"):
    print(f"File path : {filepath}")
    try:
        # On essaie d'accéder à la variable 'location_path' dans le module 'paths'
        file_path = filepath

        # Lecture du fichier CSV
        df_location = pd.read_csv(file_path)

    except AttributeError:
        print("Le chemin du fichier est introuvable.")
    except FileNotFoundError:
        print("Le fichier spécifié est introuvable.")
    return df_location

# %%
df = load_df()
df.head()
# Out:
# File path : data/fleuriste.csv
#                                                 Name Address_full  \
# 0                             FLOWERS OF A NEW WORLD          NaN
# 1                                Les Brindilles d'Or          NaN
# 2                                           Man-fado          NaN
# 3  Éleen : Fleuriste & Décoratrice d'évènements e...          NaN
# 4                                       T amo eventi          NaN
#
#         Phone_number                            Website  \
# 0  +33 9 83 35 90 51     https://www.fleursmariage.com/
# 1  +33 7 86 87 43 33  https://www.lesbrindillesdor.com/
# 2  +33 6 75 32 12 01          https://www.man-fado.com/
# 3  +33 6 14 55 22 86              https://www.eleen.fr/
# 4  +33 6 31 09 46 45        https://www.t-amoeventi.fr/
#
#                        Region  longitude   latitude  result_score  \
# 0  Provence Alpes Côte d'Azur        NaN        NaN           NaN
# 1  Provence Alpes Côte d'Azur        NaN        NaN           NaN
# 2  Provence Alpes Côte d'Azur   0.214982  48.011388      0.145913
# 3  Provence Alpes Côte d'Azur        NaN        NaN           NaN
# 4  Provence Alpes Côte d'Azur        NaN        NaN           NaN
#
#    result_score_next                      result_label  ...  \
# 0                NaN                               NaN  ...
# 1                NaN                               NaN  ...
# 2                NaN  Impasse Saint Côme 72000 Le Mans  ...
# 3                NaN                               NaN  ...
# 4                NaN                               NaN  ...
#
#           result_name       result_street result_postcode result_city  \
# 0                 NaN                 NaN             NaN         NaN
# 1                 NaN                 NaN             NaN         NaN
# 2  Impasse Saint Côme  Impasse Saint Côme         72000.0     Le Mans
# 3                 NaN                 NaN             NaN         NaN
# 4                 NaN                 NaN             NaN         NaN
#
#                  result_context  result_citycode result_oldcitycode  \
# 0                           NaN              NaN                NaN
# 1                           NaN              NaN                NaN
# 2  72, Sarthe, Pays de la Loire            72181                NaN
# 3                           NaN              NaN                NaN
# 4                           NaN              NaN                NaN
#
#   result_oldcity result_district  result_status
# 0            NaN             NaN      not-found
# 1            NaN             NaN      not-found
# 2        Le Mans             NaN             ok
# 3            NaN             NaN      not-found
# 4            NaN             NaN      not-found
#
# [5 rows x 23 columns]

# %%
df.columns = df.columns.str.lower()
df.head()
# Out:
#                                                 name address_full  \
# 0                             FLOWERS OF A NEW WORLD          NaN
# 1                                Les Brindilles d'Or          NaN
# 2                                           Man-fado          NaN
# 3  Éleen : Fleuriste & Décoratrice d'évènements e...          NaN
# 4                                       T amo eventi          NaN
#
#         phone_number                            website  \
# 0  +33 9 83 35 90 51     https://www.fleursmariage.com/
# 1  +33 7 86 87 43 33  https://www.lesbrindillesdor.com/
# 2  +33 6 75 32 12 01          https://www.man-fado.com/
# 3  +33 6 14 55 22 86              https://www.eleen.fr/
# 4  +33 6 31 09 46 45        https://www.t-amoeventi.fr/
#
#                        region  longitude   latitude  result_score  \
# 0  Provence Alpes Côte d'Azur        NaN        NaN           NaN
# 1  Provence Alpes Côte d'Azur        NaN        NaN           NaN
# 2  Provence Alpes Côte d'Azur   0.214982  48.011388      0.145913
# 3  Provence Alpes Côte d'Azur        NaN        NaN           NaN
# 4  Provence Alpes Côte d'Azur        NaN        NaN           NaN
#
#    result_score_next                      result_label  ...  \
# 0                NaN                               NaN  ...
# 1                NaN                               NaN  ...
# 2                NaN  Impasse Saint Côme 72000 Le Mans  ...
# 3                NaN                               NaN  ...
# 4                NaN                               NaN  ...
#
#           result_name       result_street result_postcode result_city  \
# 0                 NaN                 NaN             NaN         NaN
# 1                 NaN                 NaN             NaN         NaN
# 2  Impasse Saint Côme  Impasse Saint Côme         72000.0     Le Mans
# 3                 NaN                 NaN             NaN         NaN
# 4                 NaN                 NaN             NaN         NaN
#
#                  result_context  result_citycode result_oldcitycode  \
# 0                           NaN              NaN                NaN
# 1                           NaN              NaN                NaN
# 2  72, Sarthe, Pays de la Loire            72181                NaN
# 3                           NaN              NaN                NaN
# 4                           NaN              NaN                NaN
#
#   result_oldcity result_district  result_status
# 0            NaN             NaN      not-found
# 1            NaN             NaN      not-found
# 2        Le Mans             NaN             ok
# 3            NaN             NaN      not-found
# 4            NaN             NaN      not-found
#
# [5 rows x 23 columns]

# %%
selected_columns = ['name', 'address_full', 'phone_number', 'latitude', 'longitude']
#selected_columns = ['name'.upper(), 'address_full'.upper(), 'phone_number'.upper(), 'rating'.upper()]
new_df = df[selected_columns]
new_df.isna().mean()
# Out:
# name            0.000000
# address_full    0.225368
# phone_number    0.049830
# latitude        0.238392
# longitude       0.238392
# dtype: float64

# %%
new_df = new_df.dropna()

# %%
new_df.isna().mean()
# Out:
# name            0.0
# address_full    0.0
# phone_number    0.0
# rating          0.0
# latitude        0.0
# longitude       0.0
# dtype: float64

# %%
new_df.shape
# Out:
# (1142, 5)

# %%
df.to_csv("preprocessed_data/fleuriste.csv", index=False)
